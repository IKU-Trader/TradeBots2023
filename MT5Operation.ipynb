# %%
from IPython.display import display
from MT5Operation import MT5Operation
import ipywidgets as widgets

def callback(graphic):
    display(graphic)
    
operation = MT5Operation(callback)
# Out:
# MetaTrader5 connected, API Ver:  (500, 3601, '3 Mar 2023')
# ...
# ['DOWUSD', 'M5', 500]
# ([[33257.35, 33284.35, 33257.35, 33281.25],
#   [33281.25, 33289.65, 33273.05, 33287.25],
#   [33287.25, 33311.05, 33284.75, 33302.95],
#   [33303.45, 33308.75, 33297.45, 33304.65],
#   [33303.65, 33303.65, 33275.85, 33279.35],
#   [33280.35, 33287.25, 33273.95, 33282.25],
#   [33282.15, 33301.95, 33279.15, 33294.95],
#   [33295.95, 33298.95, 33266.75, 33270.15],
#   [33270.65, 33281.35, 33266.55, 33275.45],
#   [33275.95, 33280.65, 33269.75, 33273.65],
#   [33273.65, 33289.65, 33270.65, 33287.45],
#   [33287.45, 33293.15, 33279.75, 33286.25],
#   [33285.25, 33288.45, 33276.35, 33283.25],
#   [33282.75, 33286.75, 33261.95, 33273.55],
#   [33274.55, 33294.95, 33270.55, 33290.75],
#   [33291.25, 33321.25, 33290.25, 33317.05],
#   [33318.05, 33322.25, 33300.35, 33303.35],
#   [33302.35, 33320.55, 33301.85, 33318.55],
#   [33317.05, 33344.65, 33316.55, 33341.65],
# ...
